# %% [markdown]
# # 1. Library Imports
# Purpose: Import necessary libraries for preprocessing, modeling, and evaluation.

# %%
# General and Data Libraries
import os
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from collections import Counter

# Image Processing
from keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import to_categorical

# Model Building
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Data Balancing
from imblearn.over_sampling import RandomOverSampler

# Visualization Style
sns.set_style('darkgrid')
warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. Load Dataset
# Purpose: Load metadata and verify dataset structure.

# %%
# Load metadata
data = pd.read_csv('ISIC_2019_Training_GroundTruth.csv')
print("Data Shape:", data.shape)

# Check image folder structure
dataset_path = 'E:\Graduation Project\Skincancer Model'
print(os.listdir(dataset_path))
# Out:
# Data Shape: (25331, 10)
# ['AK', 'app.py', 'BCC', 'BKL', 'bo.py', 'DF', 'Final_Skin_cancer_Model.keras', 'ImranIsicModle.h5', 'ISIC_2019_Training_GroundTruth.csv', 'ISIC_2019_Training_Metadata.csv', 'MEL', 'NV', 'SCC', 'skin-disease-cnn.ipynb', 'skin_disease_cnn (1).py', 'test.ipynb', 'VASC']

# %% [markdown]
# # 3. Image Loading and Preprocessing
# ## 3.1 Define Image Loader
# Purpose: Load and resize images to the required input shape.

# %%
def load_and_resize_images(image_paths, target_size=(28, 28)):
    images = []
    for path in image_paths:
        img = load_img(path, target_size=target_size)  # Load and resize
        img_array = img_to_array(img)  # Convert to array
        images.append(img_array)
    return np.array(images)

# %% [markdown]
# ## 3.2 Load Images by Class
# Purpose: Load all images and assign corresponding labels.

# %%
# Define classes
class_folders = ['MEL', 'VASC', 'SCC', 'DF', 'NV', 'BKL', 'BCC', 'AK']

# Load images and labels
all_images, all_labels = [], []

for class_name in class_folders:
    class_folder_path = os.path.join(dataset_path, class_name)
    image_files = os.listdir(class_folder_path)
    class_images = load_and_resize_images([os.path.join(class_folder_path, img) for img in image_files])
    all_images.append(class_images)
    all_labels.append([class_name] * len(image_files))

# Combine all data
X_all = np.concatenate(all_images, axis=0)
y_all = np.concatenate(all_labels, axis=0)

print("Shape of all images:", X_all.shape)
print("Shape of all labels:", y_all.shape)
# Out:
# Shape of all images: (25331, 28, 28, 3)
# Shape of all labels: (25331,)

# %% [markdown]
# # 4. Data Preprocessing
# ## 4.1 Encode and Balance Data
# Purpose: Convert labels to one-hot encoding and balance classes using oversampling.

# %%
# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y_all)
y_one_hot = to_categorical(y_encoded)

# Reshape data for oversampling
X_reshaped = X_all.reshape(X_all.shape[0], -1)
oversampler = RandomOverSampler(random_state=42)
X_resampled, y_resampled = oversampler.fit_resample(X_reshaped, y_one_hot)

print("Class distribution after oversampling:", Counter(np.argmax(y_resampled, axis=1)))
# Out:
# Class distribution after oversampling: Counter({4: 12875, 7: 12875, 6: 12875, 3: 12875, 5: 12875, 2: 12875, 1: 12875, 0: 12875})

# %% [markdown]
# ## 4.2 Split Data
# Purpose: Create training and testing datasets

# %%
# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)
print(f"Shapes - X_train: {X_train.shape}, X_test: {X_test.shape}, y_train: {y_train.shape}, y_test: {y_test.shape}")
# Out:
# Shapes - X_train: (82400, 2352), X_test: (20600, 2352), y_train: (82400, 8), y_test: (20600, 8)

# %% [markdown]
# ## 4.3 Reshape Data
# Purpose: Restore original shape for model training.

# %%
# Reshape to (28, 28, 3)
X_train_reshaped = X_train.reshape(X_train.shape[0], 28, 28, 3)
X_test_reshaped = X_test.reshape(X_test.shape[0], 28, 28, 3)

# %% [markdown]
# # 5. Model Building
# ## 5.1 Define Model
# Purpose: Create CNN architecture with L2 regularization to prevent overfitting.

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal', kernel_regularizer=l2(0.01), input_shape=(28, 28, 3)),
    MaxPooling2D(),
    BatchNormalization(),
    Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal', kernel_regularizer=l2(0.01)),
    MaxPooling2D(),
    BatchNormalization(),
    Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal', kernel_regularizer=l2(0.01)),
    MaxPooling2D(),
    BatchNormalization(),
    Flatten(),
    Dropout(0.5),
    Dense(256, activation='relu', kernel_initializer='he_normal', kernel_regularizer=l2(0.01)),
    BatchNormalization(),
    Dense(128, activation='relu', kernel_initializer='he_normal', kernel_regularizer=l2(0.01)),
    BatchNormalization(),
    Dense(64, activation='relu', kernel_initializer='he_normal', kernel_regularizer=l2(0.01)),
    BatchNormalization(),
    Dense(8, activation='softmax')
])
# Out:
# WARNING:tensorflow:From c:\Users\Hosopa\anaconda3\envs\grad_ai\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Hosopa\anaconda3\envs\grad_ai\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %% [markdown]
# ## 5.2 Compile Model
# Purpose: Set optimizer, loss function, and evaluation metrics.

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\Hosopa\anaconda3\envs\grad_ai\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# # 6. Model Training
# Purpose: Train the CNN with callbacks for learning rate reduction and early stopping.

# %%
callbacks = [
    ReduceLROnPlateau(monitor='val_loss', patience=3, verbose=1),
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
]

history = model.fit(X_train_reshaped, y_train, validation_data=(X_test_reshaped, y_test), epochs=100, batch_size=64, callbacks=callbacks)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\Hosopa\anaconda3\envs\grad_ai\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Hosopa\anaconda3\envs\grad_ai\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1288/1288 [==============================] - 44s 31ms/step - loss: 4.4148 - accuracy: 0.4861 - val_loss: 2.1808 - val_accuracy: 0.4874 - lr: 0.0010
# Epoch 2/100
# 1288/1288 [==============================] - 39s 30ms/step - loss: 1.8894 - accuracy: 0.5874 - val_loss: 2.1108 - val_accuracy: 0.5095 - lr: 0.0010
# Epoch 3/100
# 1288/1288 [==============================] - 40s 31ms/step - loss: 1.7946 - accuracy: 0.6219 - val_loss: 2.3340 - val_accuracy: 0.4668 - lr: 0.0010
# Epoch 4/100
# 1288/1288 [==============================] - 39s 31ms/step - loss: 1.7228 - accuracy: 0.6514 - val_loss: 1.7934 - val_accuracy: 0.6116 - lr: 0.0010
# Epoch 5/100
# 1288/1288 [==============================] - 44s 34ms/step - loss: 1.6642 - accuracy: 0.6685 - val_loss: 1.6313 - val_accuracy: 0.6852 - lr: 0.0010
# Epoch 6/100
# 1288/1288 [==============================] - 40s 31ms/step - loss: 1.6129 - accuracy: 0.6817 - val_loss: 2.2746 - val_accuracy: 0.4869 - lr: 0.0010
# Epoch 7/100
# 1288/1288 [==============================] - 41s 32ms/step - loss: 1.5544 - accuracy: 0.6930 - val_loss: 1.5847 - val_accuracy: 0.6788 - lr: 0.0010
# Epoch 8/100
# 1288/1288 [==============================] - 41s 32ms/step - loss: 1.5050 - accuracy: 0.6979 - val_loss: 1.4040 - val_accuracy: 0.7261 - lr: 0.0010
# Epoch 9/100
# 1288/1288 [==============================] - 42s 33ms/step - loss: 1.4543 - accuracy: 0.7053 - val_loss: 2.1392 - val_accuracy: 0.4962 - lr: 0.0010
# Epoch 10/100
# 1288/1288 [==============================] - 41s 32ms/step - loss: 1.4233 - accuracy: 0.7075 - val_loss: 1.5588 - val_accuracy: 0.6573 - lr: 0.0010
# Epoch 11/100
# 1286/1288 [============================>.] - ETA: 0s - loss: 1.3862 - accuracy: 0.7153
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1288/1288 [==============================] - 39s 30ms/step - loss: 1.3861 - accuracy: 0.7153 - val_loss: 1.7087 - val_accuracy: 0.5884 - lr: 0.0010
# Epoch 12/100
# 1288/1288 [==============================] - 39s 30ms/step - loss: 1.0941 - accuracy: 0.7906 - val_loss: 0.8796 - val_accuracy: 0.8475 - lr: 1.0000e-04
# Epoch 13/100
# 1288/1288 [==============================] - 39s 30ms/step - loss: 0.8715 - accuracy: 0.8318 - val_loss: 0.7404 - val_accuracy: 0.8709 - lr: 1.0000e-04
# Epoch 14/100
# 1288/1288 [==============================] - 39s 30ms/step - loss: 0.7536 - accuracy: 0.8565 - val_loss: 0.6472 - val_accuracy: 0.8930 - lr: 1.0000e-04
# Epoch 15/100
# 1288/1288 [==============================] - 39s 30ms/step - loss: 0.6840 - accuracy: 0.8695 - val_loss: 0.6056 - val_accuracy: 0.8971 - lr: 1.0000e-04
# Epoch 16/100
# 1288/1288 [==============================] - 39s 30ms/step - loss: 0.6331 - accuracy: 0.8797 - val_loss: 0.5532 - val_accuracy: 0.9098 - lr: 1.0000e-04
# Epoch 17/100
# 1288/1288 [==============================] - 42s 33ms/step - loss: 0.5965 - accuracy: 0.8880 - val_loss: 0.5452 - val_accuracy: 0.9083 - lr: 1.0000e-04
# Epoch 18/100
# 1288/1288 [==============================] - 43s 34ms/step - loss: 0.5781 - accuracy: 0.8913 - val_loss: 0.5044 - val_accuracy: 0.9190 - lr: 1.0000e-04
# Epoch 19/100
# 1288/1288 [==============================] - 41s 32ms/step - loss: 0.5516 - accuracy: 0.8972 - val_loss: 0.4895 - val_accuracy: 0.9242 - lr: 1.0000e-04
# Epoch 20/100
# 1288/1288 [==============================] - 39s 30ms/step - loss: 0.5332 - accuracy: 0.9014 - val_loss: 0.4716 - val_accuracy: 0.9277 - lr: 1.0000e-04
# Epoch 21/100
# 1288/1288 [==============================] - 48s 37ms/step - loss: 0.5256 - accuracy: 0.9017 - val_loss: 0.4552 - val_accuracy: 0.9316 - lr: 1.0000e-04
# Epoch 22/100
# 1288/1288 [==============================] - 45s 35ms/step - loss: 0.5100 - accuracy: 0.9059 - val_loss: 0.4525 - val_accuracy: 0.9317 - lr: 1.0000e-04
# Epoch 23/100
# 1288/1288 [==============================] - 41s 32ms/step - loss: 0
# Epoch 70: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 1288/1288 [==============================] - 39s 30ms/step - loss: 0.2585 - accuracy: 0.9694 - val_loss: 0.3030 - val_accuracy: 0.9598 - lr: 1.0000e-05
# Epoch 71/100
# 1288/1288 [==============================] - 39s 30ms/step - loss: 0.2550 - accuracy: 0.9701 - val_loss: 0.2995 - val_accuracy: 0.9608 - lr: 1.0000e-06
# Epoch 72/100
# 1288/1288 [==============================] - 39s 30ms/step - loss: 0.2559 - accuracy: 0.9700 - val_loss: 0.2983 - val_accuracy: 0.9606 - lr: 1.0000e-06
# Epoch 73/100
# 1288/1288 [==============================] - 40s 31ms/step - loss: 0.2550 - accuracy: 0.9701 - val_loss: 0.2997 - val_accuracy: 0.9602 - lr: 1.0000e-06
# Epoch 74/100
# 1288/1288 [==============================] - 38s 30ms/step - loss: 0.2548 - accuracy: 0.9704 - val_loss: 0.3001 - val_accuracy: 0.9604 - lr: 1.0000e-06
# Epoch 75/100
# 1287/1288 [============================>.] - ETA: 0s - loss: 0.2523 - accuracy: 0.9707
# Epoch 75: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 1288/1288 [==============================] - 38s 30ms/step - loss: 0.2524 - accuracy: 0.9707 - val_loss: 0.2992 - val_accuracy: 0.9603 - lr: 1.0000e-06
# Epoch 76/100
# 1288/1288 [==============================] - 41s 32ms/step - loss: 0.2506 - accuracy: 0.9720 - val_loss: 0.3005 - val_accuracy: 0.9598 - lr: 1.0000e-07
# Epoch 77/100
# 1288/1288 [==============================] - 41s 32ms/step - loss: 0.2531 - accuracy: 0.9711 - val_loss: 0.3008 - val_accuracy: 0.9599 - lr: 1.0000e-07

# %% [markdown]
# # 7. Evaluation
# ## 7.1 Plot Training Metrics
# Purpose: Visualize training and validation accuracy/loss.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Plotting Training and Validation Metrics
def plot_training(hist):
    # Extracting accuracy and loss values
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']

    # Finding the best epochs for loss and accuracy
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    # Plot settings
    plt.figure(figsize=(20, 8))
    plt.style.use('fivethirtyeight')
    epochs = [i + 1 for i in range(len(tr_acc))]
    loss_label = f'Best Epoch = {index_loss + 1}'
    acc_label = f'Best Epoch = {index_acc + 1}'

    # Plotting Training and Validation Loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, tr_loss, 'r', label='Training Loss')
    plt.plot(epochs, val_loss, 'g', label='Validation Loss')
    plt.scatter(index_loss + 1, val_lowest, s=150, c='blue', label=loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plotting Training and Validation Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, tr_acc, 'r', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'g', label='Validation Accuracy')
    plt.scatter(index_acc + 1, acc_highest, s=150, c='blue', label=acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
plot_training(history)

# %% [markdown]
# ## 7.2 Test Performance
# Purpose: Evaluate the model on test data

# %%
test_loss, test_accuracy = model.evaluate(X_test_reshaped, y_test, verbose=1)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 644/644 [==============================] - 5s 7ms/step - loss: 0.2983 - accuracy: 0.9606
# Test Accuracy: 96.06%
# Test Loss: 0.2983

# %% [markdown]
# # 7.3 Classification Report and Confusion Matrix
# Purpose: Assess performance per class.

# %%
y_pred = np.argmax(model.predict(X_test_reshaped), axis=1)
y_true = np.argmax(y_test, axis=1)

print(classification_report(y_true, y_pred, target_names=label_encoder.classes_))

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap='Blues', xticks_rotation='vertical')
plt.show()
# Out:
# 644/644 [==============================] - 5s 7ms/step
#               precision    recall  f1-score   support
#
#           AK       1.00      1.00      1.00      2582
#          BCC       0.95      0.99      0.97      2665
#          BKL       0.94      0.99      0.96      2582
#           DF       1.00      1.00      1.00      2517
#          MEL       0.88      0.93      0.90      2612
#           NV       0.94      0.78      0.85      2557
#          SCC       0.99      1.00      1.00      2550
#         VASC       1.00      1.00      1.00      2535
#
#     accuracy                           0.96     20600
#    macro avg       0.96      0.96      0.96     20600
# weighted avg       0.96      0.96      0.96     20600

# %%
model.save("ImranIsicModlee.h5")

# %%
model.save("ImranIsicModel.keras")

# %%
idx = np.random.randint(0, len(X_test))

sample_image = X_test[idx]
true_label = np.argmax(y_test[idx])

prediction = model.predict(np.expand_dims(sample_image, axis=0))
predicted_label = np.argmax(prediction)

plt.imshow(sample_image.astype("uint8"))
plt.title(f"True: {true_label} | Pred: {predicted_label}")
plt.axis("off")
plt.show()

print("Prediction probabilities:")
print(prediction)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(sample_image.shape)
